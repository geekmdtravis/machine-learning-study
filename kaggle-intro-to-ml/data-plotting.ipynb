# %% [markdown]
# # Data Plotting

# %%
import importlib
import pandas as pd
import data_preprocessor as dpp
importlib.reload(dpp)

melbourne_data = dpp.process(pd.read_csv('melb_data.csv'))
melbourne_data.describe()
# Out:
#              rooms         price     distance     postcode     bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           bathroom          car      landsize  buildingarea    yearbuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# min       1.000000     0.000000      0.000000      0.000000  1196.000000
# 25%       1.000000     1.000000    152.000000     91.000000  1940.000000
# 50%       1.000000     1.000000    373.000000    124.000000  1970.000000
# 75%       2.000000     2.000000    628.000000    170.000000  2000.000000
# max       8.000000    10.000000  37000.000000   3112.000000  2018.000000
#
#          lattitude   longtitude  propertycount
# count  6196.000000  6196.000000    6196.000000
# mean    -37.807904   144.990201    7435.489509
# std       0.075850     0.099165    4337.698917
# min     -38.164920   144.542370     389.000000
# 25%     -37.855438   144.926198    4383.750000
# 50%     -37.802250   144.995800    6567.000000
# 75%     -37.758200   145.052700   10175.000000
# max     -37.457090   145.526350   21650.000000

# %%
melbourne_data.head()
# Out:
#        suburb          address  rooms type      price method sellerg  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         date  distance  postcode  ...  bathroom  car  landsize  buildingarea  \
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 6  7/05/2016       2.5    3067.0  ...       2.0  0.0     245.0         210.0
# 7  8/10/2016       2.5    3067.0  ...       1.0  2.0     256.0         107.0
#
#    yearbuilt  councilarea lattitude  longtitude             regionname  \
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
# 6     1910.0        Yarra  -37.8024    144.9993  Northern Metropolitan
# 7     1890.0        Yarra  -37.8060    144.9954  Northern Metropolitan
#
#   propertycount
# 1        4019.0
# 2        4019.0
# 4        4019.0
# 6        4019.0
# 7        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Let's confirm there are now NaN values...

# %%
melbourne_data.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'price', 'method', 'sellerg',
#        'date', 'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
#        'landsize', 'buildingarea', 'yearbuilt', 'councilarea', 'lattitude',
#        'longtitude', 'regionname', 'propertycount'],
#       dtype='object')

# %%
for col in melbourne_data.columns:
    print(f'{col} has NaN') if melbourne_data[col].hasnans  else None

# %% [markdown]
# ## Selecting the Prediction Target

# %%
model_features = [ 'rooms', 
        'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
       'landsize',  'lattitude',
       'longtitude',  'propertycount']


y = melbourne_data.price
X = melbourne_data[model_features]

X.describe()
# Out:
#              rooms     distance     postcode     bedroom2     bathroom  \
# count  6196.000000  6196.000000  6196.000000  6196.000000  6196.000000
# mean      2.931407     9.751097  3101.947708     2.902034     1.576340
# std       0.971079     5.612065    86.421604     0.970055     0.711362
# min       1.000000     0.000000  3000.000000     0.000000     1.000000
# 25%       2.000000     5.900000  3044.000000     2.000000     1.000000
# 50%       3.000000     9.000000  3081.000000     3.000000     1.000000
# 75%       4.000000    12.400000  3147.000000     3.000000     2.000000
# max       8.000000    47.400000  3977.000000     9.000000     8.000000
#
#                car      landsize    lattitude   longtitude  propertycount
# count  6196.000000   6196.000000  6196.000000  6196.000000    6196.000000
# mean      1.573596    471.006940   -37.807904   144.990201    7435.489509
# std       0.929947    897.449881     0.075850     0.099165    4337.698917
# min       0.000000      0.000000   -38.164920   144.542370     389.000000
# 25%       1.000000    152.000000   -37.855438   144.926198    4383.750000
# 50%       1.000000    373.000000   -37.802250   144.995800    6567.000000
# 75%       2.000000    628.000000   -37.758200   145.052700   10175.000000
# max      10.000000  37000.000000   -37.457090   145.526350   21650.000000

# %%
X.head()
# Out:
#    rooms  distance  postcode  bedroom2  bathroom  car  landsize  lattitude  \
# 1      2       2.5    3067.0       2.0       1.0  0.0     156.0   -37.8079
# 2      3       2.5    3067.0       3.0       2.0  0.0     134.0   -37.8093
# 4      4       2.5    3067.0       3.0       1.0  2.0     120.0   -37.8072
# 6      3       2.5    3067.0       4.0       2.0  0.0     245.0   -37.8024
# 7      2       2.5    3067.0       2.0       1.0  2.0     256.0   -37.8060
#
#    longtitude  propertycount
# 1    144.9934         4019.0
# 2    144.9944         4019.0
# 4    144.9941         4019.0
# 6    144.9993         4019.0
# 7    144.9954         4019.0

# %% [markdown]
# ## Normalizing our Data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))
X.describe()
# Out:
#                  0            1            2            3            4  \
# count  6196.000000  6196.000000  6196.000000  6196.000000  6196.000000
# mean      0.275915     0.205719     0.104348     0.322448     0.082334
# std       0.138726     0.118398     0.088456     0.107784     0.101623
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.142857     0.124473     0.045036     0.222222     0.000000
# 50%       0.285714     0.189873     0.082907     0.333333     0.000000
# 75%       0.428571     0.261603     0.150461     0.333333     0.142857
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  5            6            7            8            9
# count  6196.000000  6196.000000  6196.000000  6196.000000  6196.000000
# mean      0.157360     0.012730     0.504381     0.455122     0.331428
# std       0.092995     0.024255     0.107159     0.100779     0.204021
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.100000     0.004108     0.437227     0.390077     0.187891
# 50%       0.100000     0.010081     0.512369     0.460812     0.290579
# 75%       0.200000     0.016973     0.574601     0.518639     0.460279
# max       1.000000     1.000000     1.000000     1.000000     1.000000

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.8, random_state=1)
lr_model = LinearRegression()
lr_model.fit(train_X, train_y)

pred_Y = lr_model.predict(val_X)
mean_absolute_error(val_y, pred_Y)
# Out:
# 312424.8210104571

# %%
train_x_df = pd.DataFrame(train_X)
train_x_df.head()
# Out:
#              0         1         2         3         4    5         6  \
# 2629  0.142857  0.080169  0.211873  0.111111  0.000000  0.1  0.000000
# 4123  0.285714  0.286920  0.151484  0.333333  0.142857  0.2  0.007730
# 5872  0.285714  0.198312  0.025589  0.333333  0.142857  0.2  0.014297
# 2766  0.142857  0.236287  0.074719  0.222222  0.000000  0.1  0.009730
# 3895  0.285714  0.172996  0.012282  0.222222  0.000000  0.1  0.000000
#
#              7         8         9
# 2629  0.458048  0.402986  0.388458
# 4123  0.408883  0.562034  0.150181
# 5872  0.457525  0.304295  0.223085
# 2766  0.618256  0.490894  1.000000
# 3895  0.520633  0.330118  0.219604

# %%
val_x_def = pd.DataFrame(val_X)
val_x_def.head()
# Out:
#              0         1         2         3         4    5         6  \
# 3273  0.285714  0.280591  0.020471  0.333333  0.285714  0.2  0.005973
# 4775  0.428571  0.130802  0.125896  0.444444  0.142857  0.2  0.014270
# 2192  0.285714  0.059072  0.000000  0.333333  0.142857  0.1  0.000000
# 3178  0.285714  0.128692  0.186285  0.333333  0.142857  0.2  0.028081
# 1987  0.714286  0.118143  0.103378  0.666667  0.714286  0.3  0.036054
#
#              7         8         9
# 3273  0.556800  0.302577  0.180048
# 4775  0.465550  0.508882  0.286581
# 2192  0.502126  0.433678  0.804619
# 3178  0.425413  0.446788  0.604440
# 1987  0.511450  0.492215  0.467617

# %%
my_house = pd.DataFrame([[3, 1, 6155, 5, 5, 3, 15000, -37.8079,	144.9934, 6]])
scaled = scaler.fit_transform(my_house) 
lr_model.predict(scaled)
# Out:
# array([716114.63972727])
